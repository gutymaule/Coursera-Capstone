# %% [markdown]
# # CAPSTONE PROJECT - Battle of the Neighborhoods

# %% [markdown]
# ## 1 - Introduction to the Problem

# %% [markdown]
#  Over hundreds of years, millions of Chinese immigrants came to the United States. Chinese restaurants spreed all over the US, and today is one of the most popular foods in America. As an investor, I will search the best place to open a Chinese Resturant in Manhanttan, which is were I live. I will find where there is less competition to open a good Chinese Restaurant

# %% [markdown]
# ## 2 - Data

# %% [markdown]
# To find the best location to open a Chinese restaurant, I will use New York City data that contains the latitude and longitude of all Chinese restaurants in Manhattan. The data is public available: https://cocl.us/new_york_dataset.</p> To have more information on each Chinese restaurants, I will use the Foursquare API.
